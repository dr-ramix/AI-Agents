# %% [markdown]
# # Question and Answer

# %% [markdown]
# #### Imports

# %%
import os
import openai
import sys
from dotenv import load_dotenv, find_dotenv

import numpy as np


#Embedding
from langchain_openai import OpenAIEmbeddings

#Vector Database
from langchain_chroma import Chroma

#Loader
from langchain_community.document_loaders import PyPDFLoader

#Splitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFDirectoryLoader

#Self-Query Retriever

from langchain_openai import ChatOpenAI
from langchain_classic.chains.query_constructor.schema import AttributeInfo
from langchain_classic.retrievers.self_query.base import SelfQueryRetriever

#Retrieve Information Compression
from langchain_classic.retrievers import ContextualCompressionRetriever
from langchain_classic.retrievers.document_compressors import LLMChainExtractor

#RetrievalQA chain
from langchain_classic.chains import RetrievalQA

# %% [markdown]
# ##### OpenAI API KEX

# %%
sys.path.append('../..')
_ = load_dotenv(find_dotenv()) 
api_key = os.environ['OPENAI_API_KEY']

# %% [markdown]
# #### Embedding and VectorDB

# %%
# 1. Load all PDFs from the ./docs directory
loader = PyPDFDirectoryLoader("./docs")
documents = loader.load()

# 2. Split documents into chunks
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)
docs = text_splitter.split_documents(documents)

# 3. Create embeddings
embedding = OpenAIEmbeddings()

# 4. Store chunks in Chroma DB (persist to ./docs)
vectordb = Chroma.from_documents(
    documents=docs,
    embedding=embedding,
    persist_directory="./docs"
)
print("PDFs loaded into vector database successfully.")
# Out:
# PDFs loaded into vector database successfully.

# %%
print(vectordb._collection.count())
# Out:
# 3040

# %% [markdown]
# #### Similarity Search in VectorDB

# %%
question = "What is Neural Network Quantum State?"
similar_docs = vectordb.similarity_search(question, k = 3)
len(similar_docs)
# Out:
# 3

# %% [markdown]
# #### LLM Model

# %%
llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)

# %% [markdown]
# ##### RetrievalQA chain

# %%
qa_chain = RetrievalQA.from_chain_type(
    llm,
    retriever = vectordb.as_retriever()
)

# %%
result = qa_chain({"query": question})
# Out:
# /var/folders/33/28753zc950g7jnqk3b6ljhdr0000gn/T/ipykernel_48844/4094420968.py:1: LangChainDeprecationWarning: The method `Chain.__call__` was deprecated in langchain-classic 0.1.0 and will be removed in 1.0. Use `invoke` instead.
#   result = qa_chain({"query": question})
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File /opt/miniconda3/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/openai/_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File /opt/miniconda3/lib/python3.13/contextlib.py:162, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     161 try:
# --> 162     self.gen.throw(value)
#     163 except StopIteration as exc:
#     164     # Suppress StopIteration *unless* it's the same exception that
#     165     # was passed to throw().  This prevents a StopIteration
#     166     # raised inside the "with" statement from being suppressed.
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 result = qa_chain({"query": question})
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_core/_api/deprecation.py:188, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     186     warned = True
#     187     emit_warning()
# --> 188 return wrapped(*args, **kwargs)
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_classic/chains/base.py:413, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     380 """Execute the chain.
#     381
#     382 Args:
#    (...)    404         `Chain.output_keys`.
#     405 """
#     406 config = {
#     407     "callbacks": callbacks,
#     408     "tags": tags,
#     409     "metadata": metadata,
#     410     "run_name": run_name,
#     411 }
# --> 413 return self.invoke(
#     414     inputs,
#     415     cast("RunnableConfig", {k: v for k, v in config.items() if v is not None}),
#     416     return_only_outputs=return_only_outputs,
#     417     include_run_info=include_run_info,
#     418 )
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_classic/chains/base.py:167, in Chain.invoke(self, input, config, **kwargs)
#     164 try:
#     165     self._validate_inputs(inputs)
#     166     outputs = (
# --> 167         self._call(inputs, run_manager=run_manager)
#     168         if new_arg_supported
#     169         else self._call(inputs)
#     170     )
#     172     final_outputs: dict[str, Any] = self.prep_outputs(
#     173         inputs,
#     174         outputs,
#     175         return_only_outputs,
#     176     )
#     177 except BaseException as e:
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_classic/chains/retrieval_qa/base.py:157, in BaseRetrievalQA._call(self, inputs, run_manager)
#     153 accepts_run_manager = (
#     154     "run_manager" in inspect.signature(self._get_docs).parameters
#     155 )
#     156 if accepts_run_manager:
# --> 157     docs = self._get_docs(question, run_manager=_run_manager)
#     158 else:
#     159     docs = self._get_docs(question)  # type: ignore[call-arg]
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_classic/chains/retrieval_qa/base.py:281, in RetrievalQA._get_docs(self, question, run_manager)
#     274 def _get_docs(
#     275     self,
#     276     question: str,
#     277     *,
#     278     run_manager: CallbackManagerForChainRun,
#     279 ) -> list[Document]:
#     280     """Get docs."""
# --> 281     return self.retriever.invoke(
#     282         question,
#     283         config={"callbacks": run_manager.get_child()},
#     284     )
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_core/retrievers.py:216, in BaseRetriever.invoke(self, input, config, **kwargs)
#     214 kwargs_ = kwargs if self._expects_other_args else {}
#     215 if self._new_arg_supported:
# --> 216     result = self._get_relevant_documents(
#     217         input, run_manager=run_manager, **kwargs_
#     218     )
#     219 else:
#     220     result = self._get_relevant_documents(input, **kwargs_)
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_core/vectorstores/base.py:1033, in VectorStoreRetriever._get_relevant_documents(self, query, run_manager, **kwargs)
#    1031 kwargs_ = self.search_kwargs | kwargs
#    1032 if self.search_type == "similarity":
# -> 1033     docs = self.vectorstore.similarity_search(query, **kwargs_)
#    1034 elif self.search_type == "similarity_score_threshold":
#    1035     docs_and_similarities = (
#    1036         self.vectorstore.similarity_search_with_relevance_scores(
#    1037             query, **kwargs_
#    1038         )
#    1039     )
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_chroma/vectorstores.py:695, in Chroma.similarity_search(self, query, k, filter, **kwargs)
#     677 def similarity_search(
#     678     self,
#     679     query: str,
#    (...)    682     **kwargs: Any,
#     683 ) -> list[Document]:
#     684     """Run similarity search with Chroma.
#     685
#     686     Args:
#    (...)    693         List of documents most similar to the query text.
#     694     """
# --> 695     docs_and_scores = self.similarity_search_with_score(
#     696         query,
#     697         k,
#     698         filter=filter,
#     699         **kwargs,
#     700     )
#     701     return [doc for doc, _ in docs_and_scores]
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_chroma/vectorstores.py:795, in Chroma.similarity_search_with_score(self, query, k, filter, where_document, **kwargs)
#     787     results = self.__query_collection(
#     788         query_texts=[query],
#     789         n_results=k,
#    (...)    792         **kwargs,
#     793     )
#     794 else:
# --> 795     query_embedding = self._embedding_function.embed_query(query)
#     796     results = self.__query_collection(
#     797         query_embeddings=[query_embedding],
#     798         n_results=k,
#    (...)    801         **kwargs,
#     802     )
#     804 return _results_to_docs_and_scores(results)
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:674, in OpenAIEmbeddings.embed_query(self, text, **kwargs)
#     664 """Call out to OpenAI's embedding endpoint for embedding query text.
#     665
#     666 Args:
#    (...)    671     Embedding for the text.
#     672 """
#     673 self._ensure_sync_client_available()
# --> 674 return self.embed_documents([text], **kwargs)[0]
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:625, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size, **kwargs)
#     622 # NOTE: to keep things simple, we assume the list may contain texts longer
#     623 #       than the maximum context and use length-safe embedding function.
#     624 engine = cast(str, self.deployment)
# --> 625 return self._get_len_safe_embeddings(
#     626     texts, engine=engine, chunk_size=chunk_size, **kwargs
#     627 )
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/langchain_openai/embeddings/base.py:514, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size, **kwargs)
#     512 batched_embeddings: list[list[float]] = []
#     513 for i in _iter:
# --> 514     response = self.client.create(
#     515         input=tokens[i : i + _chunk_size], **client_kwargs
#     516     )
#     517     if not isinstance(response, dict):
#     518         response = response.model_dump()
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/openai/resources/embeddings.py:132, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     126             embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     127                 base64.b64decode(data), dtype="float32"
#     128             ).tolist()
#     130     return obj
# --> 132 return self._post(
#     133     "/embeddings",
#     134     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     135     options=make_request_options(
#     136         extra_headers=extra_headers,
#     137         extra_query=extra_query,
#     138         extra_body=extra_body,
#     139         timeout=timeout,
#     140         post_parser=parser,
#     141     ),
#     142     cast_to=CreateEmbeddingResponse,
#     143 )
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/openai/_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Desktop/projects/ai_agents/venv/lib/python3.13/site-packages/openai/_base_client.py:1014, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1011         continue
#    1013     log.debug("Raising connection error")
# -> 1014     raise APIConnectionError(request=request) from err
#    1016 log.debug(
#    1017     'HTTP Response: %s %s "%i %s" %s',
#    1018     request.method,
#    (...)   1022     response.headers,
#    1023 )
#    1024 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.
